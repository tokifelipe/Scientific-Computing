# %% [markdown]
# <center>
#     <img src="http://sct.inf.utfsm.cl/wp-content/uploads/2020/04/logo_di.png" style="width:60%">
#     <h1> INF285 - Computación Científica </h1>
#     <h2> Tarea 2 - Código Base</h2>
#     <h2> [S]cientific [C]omputing [T]eam </a> </h2>
#     <h2> 2024-2</h2>
# </center>

# %% [markdown]
# # Consultas
#
# * Enviar a: **tareas.inf285@gmail.com**
# * Se recibirán consultas en **tres** bloques:
# 1. El primer bloque será desde las 12:15 hrs. hasta las 17:00 hrs. del día jueves, donde todas las preguntas recibidas dentro de este bloque se responderán con seguridad a partir de las 17:01 hrs. del día jueves.
# 2. El segundo bloque de consultas será desde las 17:01 hrs. del día jueves hasta las 08:15 hrs. del día viernes, donde las preguntas recibidas dentro de este bloque horario se responderán con seguridad a partir de las 08:16 hrs. del día viernes.
# 3. El tercer, y último bloque, de consultas será desde las 08:16 hrs. hasta las 14:30 hrs. del día viernes, donde las preguntas recibidas dentro de este bloque horario se responderán con seguridad a partir de las 14:31 hrs. del día viernes.

# %% [markdown]
# # Librerías (no utilizar liberías adicionales)

# %%
# ejecute una sola vez en caso de estar en un entorno virtual (quizás se solicite instalar ipykernel previamente)
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==4.6.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 1)) (4.6.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: asttokens==2.4.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: async-lru==2.0.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: attrs==24.2.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 7)) (24.2.0)
# Requirement already satisfied: babel==2.16.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 8)) (2.16.0)
# Requirement already satisfied: beautifulsoup4==4.12.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 9)) (4.12.3)
# Requirement already satisfied: bleach==6.1.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 10)) (6.1.0)
# Requirement already satisfied: certifi==2024.8.30 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 11)) (2024.8.30)
# Requirement already satisfied: cffi==1.17.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 12)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.3.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: comm==0.2.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 14)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: cycler==0.12.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.6 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 17)) (1.8.6)
# Requirement already satisfied: decorator==5.1.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 18)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: exceptiongroup==1.2.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 20)) (1.2.2)
# Requirement already satisfied: executing==2.1.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 21)) (2.1.0)
# Requirement already satisfied: fastjsonschema==2.20.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 22)) (2.20.0)
# Requirement already satisfied: fonttools==4.54.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 23)) (4.54.1)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 24)) (1.5.1)
# Requirement already satisfied: h11==0.14.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 25)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.6 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 26)) (1.0.6)
# Requirement already satisfied: httpx==0.27.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 27)) (0.27.2)
# Requirement already satisfied: idna==3.10 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 28)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 29)) (6.29.5)
# Requirement already satisfied: ipympl==0.9.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 30)) (0.9.4)
# Requirement already satisfied: ipython==8.27.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 31)) (8.27.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 32)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.1.5 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 33)) (8.1.5)
# Requirement already satisfied: isoduration==20.11.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 34)) (20.11.0)
# Requirement already satisfied: jedi==0.19.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 35)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 36)) (3.1.4)
# Requirement already satisfied: joblib==1.4.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 37)) (1.4.2)
# Requirement already satisfied: json5==0.9.25 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 38)) (0.9.25)
# Requirement already satisfied: jsonpointer==3.0.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 39)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 40)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 41)) (2023.12.1)
# Requirement already satisfied: jupyter-events==0.10.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 42)) (0.10.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 43)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 44)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 45)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.14.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 46)) (2.14.2)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 47)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.2.5 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 48)) (4.2.5)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 49)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 50)) (2.27.3)
# Requirement already satisfied: jupyterlab_widgets==3.0.13 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 51)) (3.0.13)
# Requirement already satisfied: kiwisolver==1.4.7 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 52)) (1.4.7)
# Requirement already satisfied: MarkupSafe==2.1.5 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 53)) (2.1.5)
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 54)) (3.9.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 55)) (0.1.7)
# Requirement already satisfied: mistune==3.0.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 56)) (3.0.2)
# Requirement already satisfied: nbclient==0.10.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 57)) (0.10.0)
# Requirement already satisfied: nbconvert==7.16.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 58)) (7.16.4)
# Requirement already satisfied: nbformat==5.10.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 59)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 60)) (1.6.0)
# Requirement already satisfied: notebook==7.2.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 61)) (7.2.2)
# Requirement already satisfied: notebook_shim==0.2.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 62)) (0.2.4)
# Requirement already satisfied: numpy==2.1.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 63)) (2.1.1)
# Requirement already satisfied: overrides==7.7.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 64)) (7.7.0)
# Requirement already satisfied: packaging==24.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 65)) (24.1)
# Requirement already satisfied: pandocfilters==1.5.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 66)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 67)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 68)) (4.9.0)
# Requirement already satisfied: pillow==10.4.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 69)) (10.4.0)
# Requirement already satisfied: platformdirs==4.3.6 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 70)) (4.3.6)
# Requirement already satisfied: prometheus_client==0.21.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 71)) (0.21.0)
# Requirement already satisfied: prompt_toolkit==3.0.48 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 72)) (3.0.48)
# Requirement already satisfied: psutil==6.0.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 73)) (6.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 74)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 75)) (0.2.3)
# Requirement already satisfied: pycparser==2.22 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 76)) (2.22)
# Requirement already satisfied: Pygments==2.18.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 77)) (2.18.0)
# Requirement already satisfied: pyparsing==3.1.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 78)) (3.1.4)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 79)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==2.0.7 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 80)) (2.0.7)
# Requirement already satisfied: PyYAML==6.0.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 81)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 82)) (26.2.0)
# Requirement already satisfied: referencing==0.35.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 83)) (0.35.1)
# Requirement already satisfied: requests==2.32.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 84)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 85)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 86)) (0.1.1)
# Requirement already satisfied: rpds-py==0.20.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 87)) (0.20.0)
# Requirement already satisfied: scikit-learn==1.5.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 88)) (1.5.2)
# Requirement already satisfied: scipy==1.14.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 89)) (1.14.1)
# Requirement already satisfied: Send2Trash==1.8.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 90)) (1.8.3)
# Requirement already satisfied: six==1.16.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 91)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 92)) (1.3.1)
# Requirement already satisfied: soupsieve==2.6 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 93)) (2.6)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 94)) (0.6.3)
# Requirement already satisfied: terminado==0.18.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 95)) (0.18.1)
# Requirement already satisfied: threadpoolctl==3.5.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 96)) (3.5.0)
# Requirement already satisfied: tinycss2==1.3.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 97)) (1.3.0)
# Requirement already satisfied: tomli==2.0.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 98)) (2.0.1)
# Requirement already satisfied: tornado==6.4.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 99)) (6.4.1)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 100)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20240906 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 101)) (2.9.0.20240906)
# Requirement already satisfied: typing_extensions==4.12.2 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 102)) (4.12.2)
# Requirement already satisfied: uri-template==1.3.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 103)) (1.3.0)
# Requirement already satisfied: urllib3==2.2.3 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 104)) (2.2.3)
# Requirement already satisfied: wcwidth==0.2.13 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 105)) (0.2.13)
# Requirement already satisfied: webcolors==24.8.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 106)) (24.8.0)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 107)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 108)) (1.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.13 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from -r requirements.txt (line 109)) (4.0.13)
# Requirement already satisfied: colorama in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from ipython==8.27.0->-r requirements.txt (line 31)) (0.4.6)
# Requirement already satisfied: pywin32>=300 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from jupyter_core==5.7.2->-r requirements.txt (line 45)) (306)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from jupyter_server==2.14.2->-r requirements.txt (line 46)) (2.0.13)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\felip\documents\github\repositorios\codigos_python\scientific-computing\tarea_2024_2\tarea_2\.venv\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 48)) (75.1.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np 
from matplotlib.widgets import Slider

# %% [markdown]
# # Contexto
#
# ¡Los marcianos han invadido la tierra!, su propósito final es descubrir los secretos de la especie humana para el dominio mundial. Actualmente están en fase de investigación, quieren estudiar la anatomía humana pero son muy flojos como para abducir personas y estudiarlos ellos mismos, por lo que recurren al robo de imágenes por resonancia magnética.
#
# La imagen por resonancia magnética (IRM) es una herramienta ampliamente utilizada en el área de la medicina para la obtención de características detalladas de distintas partes internas del cuerpo, lo cual permite diagnosticar y estudiar diversas condiciones de salud. Nos enfocaremos en la visualización tridimensional de una resonancia magnética de una cabeza, la cual se compone de un conjunto de imágenes bidimensionales en escala de grises.
#
# Los marcianos han escapado airosos de la faz de la tierra en su nave espacial con las imágenes, pero la especie humana fue capaz de codificar en PCA el conjunto imágenes obtenidas por el resonador magnético, tema que los marcianos ignoran y por lo que pedirán su ayuda por sus conocimientos de *Computación Científica*.
#
# El objetivo principal es explorar técnicas de compresión y reconstrucción de datos haciendo uso de herramientas como el Análisis de Componentes Principales (PCA), además de redimensionar a partir de un solo eje de imágenes la imagen completa tridimensional.
#
# <p align="center">
#   <img src="img.jpeg" alt="drawing" style="margin:auto;width:500px;"/>
# </p>

# %% [markdown]
# # Funciones entregadas (no debe modificarlas)

# %%
class SliceViewer3D:
    def __init__(self, H, fun):
        self.H = H
        self.shape = H.shape
        self.fun = fun
        self.current_slice_axial = self.shape[0] // 2
        self.current_slice_coronal = self.shape[1] // 2
        self.current_slice_sagittal = self.shape[2] // 2

        self.A, self.B, self.C = self.fun(H, coor=(self.current_slice_axial, self.current_slice_coronal, self.current_slice_sagittal))

        self.fig, (self.axial_ax, self.coronal_ax, self.sagittal_ax) = plt.subplots(1, 3, figsize=(15, 5))
        
        self.axial_slider_ax = self.fig.add_axes([0.1, 0.01, 0.2, 0.03])
        self.coronal_slider_ax = self.fig.add_axes([0.4, 0.01, 0.2, 0.03])
        self.sagittal_slider_ax = self.fig.add_axes([0.7, 0.01, 0.2, 0.03])

        self.axial_slider = Slider(self.axial_slider_ax, 'Axial', 1, self.shape[0], valinit=self.current_slice_axial + 1, valstep=1)
        self.coronal_slider = Slider(self.coronal_slider_ax, 'Coronal', 1, self.shape[1], valinit=self.current_slice_coronal + 1, valstep=1)
        self.sagittal_slider = Slider(self.sagittal_slider_ax, 'Sagittal', 1, self.shape[2], valinit=self.current_slice_sagittal, valstep=1)

        self.update_slices()

        self.axial_slider.on_changed(self.update_axial_slice)
        self.coronal_slider.on_changed(self.update_coronal_slice)
        self.sagittal_slider.on_changed(self.update_sagittal_slice)

    def update_slices(self):
        self.A, self.B, self.C = self.fun(self.H, coor=(self.current_slice_axial, self.current_slice_coronal, self.current_slice_sagittal))

        self.axial_ax.clear()
        self.axial_ax.imshow(self.A, cmap='gray')
        self.axial_ax.axhline(self.current_slice_coronal, color='r') 
        self.axial_ax.axvline(self.current_slice_sagittal, color='g') 
        self.axial_ax.set_title(f'Axial Slice {self.current_slice_axial + 1}/{self.shape[0]}')

        self.coronal_ax.clear()
        self.coronal_ax.imshow(self.B, cmap='gray')
        self.coronal_ax.axhline(self.current_slice_sagittal, color='g')
        self.coronal_ax.axvline(self.current_slice_axial, color='b')
        self.coronal_ax.set_title(f'Coronal Slice {self.current_slice_coronal + 1}/{self.shape[1]}')

        self.sagittal_ax.clear()
        self.sagittal_ax.imshow(self.C, cmap='gray')
        self.sagittal_ax.axhline(self.current_slice_coronal, color='r')
        self.sagittal_ax.axvline(self.current_slice_axial, color='b')
        self.sagittal_ax.set_title(f'Sagittal Slice {self.current_slice_sagittal + 1}/{self.shape[2]}')

        plt.draw()

    def update_axial_slice(self, value):
        self.current_slice_axial = int(value)
        self.update_slices()

    def update_coronal_slice(self, value):
        self.current_slice_coronal = int(value)
        self.update_slices()

    def update_sagittal_slice(self, value):
        self.current_slice_sagittal = int(value)
        self.update_slices()

# %% [markdown]
# # Pregunta 1
# Se sabe que el conjunto de imágenes original estaba distribuido en un tensor, es decir, una matriz tridimensional $H \in \mathbb{R}^{p \times q \times r}$, donde $p$ es la cantidad de imágenes, $q$ representa el alto de la imagen y $r$ es el ancho de la imagen. Para aplicar *PCA*, las imágenes se colocaron sobre una grilla dentro de una matriz $M \in \mathbb{R}^{m \times n}$ de la siguiente forma: la cantidad de imágenes hacia la derecha corresponde a $\lfloor \sqrt{p} \rfloor$, y la cantidad de imágenes hacia abajo son tantas como sean necesarias para rellenar con las $p$ imágenes, las cuales se rellenan según su orden de llegada de izquierda a derecha y de arriba a abajo. Veamos un ejemplo con $p=13$:
#
# La cantidad de imágenes hacia la derecha corresponde a $\lfloor \sqrt{13} \rfloor = 3$, la matriz $M$ se ve de la siguiente manera (tenga en cuenta que $I_{i} \in \mathbb{R}^{q \times r},i=1,...,p$ es la i-ésima imagen):
# $$
# M = \begin{pmatrix}
# I_1 & I_2 & I_3 \\
# I_4 & I_5 & I_6 \\
# I_7 & I_8 & I_9 \\
# I_{10} & I_{11} & I_{12} \\
# I_{13} &  &
# \end{pmatrix}
# $$
#
# Note que se dejaron espacios en blanco al final. Si consideramos que cada imagen $I_{i}$ tiene dimensiones $q \times r$ (sin RGB, es decir, un solo canal), entonces tendremos una matriz $M$ de dimensiones $m \times n$, con $m=5q$ y $n=3r$. Finalmente aplicamos *PCA* a esta matriz $M$, obteniendo los siguientes resultados:
#
# - *Vh*: array con las componentes principales de $M$.
# - *Y*: array con los coeficientes proyectados de $M$.
# - *S*: array con los valores singulares de $M$.
# - *mu*: array con los promedios de las columnas de $M$
#
# Lamentablemente durante el escape marciano solo se pudieron recuperar las primeras 400 componentes principales, los primeros 400 coeficientes proyectados, los primeros 400 valores singulares y el array de los promedios de las columnas de $M$. Estas variables las puede cargar con el siguiente código:

# %%
# No modifique, solo ejecute

# Carga los primeros 400 componentes principales
with open("vars/Vhk400.npy", 'rb') as f:
  Vh = np.load(f)

# Carga los primeros 400 coeficientes proyectados
with open("vars/Yk400.npy", 'rb') as f:
  Y = np.load(f)

# Carga los primeros 400 valores singulares
with open("vars/Sk400.npy", 'rb') as f:
  S = np.load(f)

# Carga un array con los promedios de las columnas
with open("vars/muk400.npy", 'rb') as f:
  mu = np.load(f)

# %% [markdown]
# 1. **(10 puntos)** Implemente la función `rebuild_M` que reciba el array de componentes principales $Vh$, el array de coeficientes proyectados $Y$, el array con los promedios de las columnas $mu$ y la cantidad de componentes $k$ a considerar en la reconstrucción.

# %%
def rebuild_M(Vh, Y, mu, k):
  """
  input:
  Vh  :(ndarray) array of the principal components.
  Y   :(ndarray) array of projected coefficients.
  mu  :(ndarray) 1D array of averages per column of original data.
  k   :(int)     number of principal components to use.

  output:
  M   :(ndarray) array with data of the reconstructed image with k principal components.
  """
  # Centralizamos los datos
  M_central_k= Y[:, :k] @ Vh[:k, :]

  # Reconstrucción de la matriz M
  M = M_central_k + mu

  #--------------------------------
  return M

# %% [markdown]
# # Pregunta 2
#
# Como es sabido, la matriz original es un tensor tridimensional, a continuacion se debera lograr obtener la forma original de esta a partir de $M$, ademas de mostrar como se deberian ver los distintos cortes a traves de toda la imagen.

# %% [markdown]
# 2.1 **(20 puntos)** Implemente la función `M_to_tensor` la cual recibe la matriz $M \in \mathbb{R}^{m \times n}$ y *original_shape* que corresponde a la forma original $(p,q,r)$ de $H$ y retorna la reconstrucción de $H \in \mathbb{R}^{p \times q \times r}$.

# %%
def M_to_tensor(M, original_shape=(327, 480, 480)):
  """
  input:
  M              :(ndarray) rebuilt matrix with the images.
  original_shape :(tuple)   original shape of the tensor in the form (p,q,r).

  output:
  H              :(ndarray) rebuilt tensor representing the head with shape (p,q,r).
  """
  # acá va su código
  #--------------------------------
  p=original_shape[0]
  q=original_shape[1]
  r=original_shape[2]

  #Dimensiones de M
  m, n = M.shape
  #Cantidad de imágenes hacia la derecha
  c_der= int(np.floor(np.sqrt(p)))
  #Tantas filas como sean necesarias para rellenar con p imagenes
  c_filas = int(np.ceil(p / c_der))
  #Creando H
  #La matriz H tendrá "c_filas" filas , cada fila tendrá q submatrices, cada submatriz será una imagen de r columnas
  H = M.reshape((c_filas,q,c_der, r)).transpose(0, 2, 1, 3).reshape((c_filas * c_der, q, r))[:p]
  #--------------------------------
  return H

# %% [markdown]
# 2.2 **(5 puntos)** Implemente la funcion `get_views` la cual recibe la matriz reconstruida $H \in \mathbb{R}^{p \times q \times r}$ y la coordenada $(i,j,k) \in \mathbb{Z}³$ con $i \in [1,p]$ , $j \in [1,q]$ y $k \in [1,r]$. Esta función retorna la i-ésima vista del plano axial, j-ésima vista del plano coronal y k-ésima vista del plano sagital, desde la reconstrucción $H$ que representa la cabeza tridimensional.
#
# *Hint: for more information about each plane visit https://en.wikipedia.org/wiki/Anatomical_plane and make sure the views are well oriented.*

# %%
def get_views(H, coor):
  """
  input:
  H              :(ndarray) rebuilt tensor representing the head.
  coor           :(tuple)   coordinates of the views to be extracted, example: (164, 240, 240).

  output:
  AXIAL_VIEW     :(ndarray) i-th image from the axial plane.
  CORONAL_VIEW   :(ndarray) j-th image from the coronal plane.
  SAGITAL_VIEW   :(ndarray) k-th image from the sagital plane.
  """
  i=coor[0]
  j=coor[1]
  k=coor[2]
  # selecciona la i-ésima matriz bidimensional en el eje axial (primer eje) de la matriz tridimensional H.
  AXIAL_VIEW = H[i, :, :]
  # selecciona la k-ésima matriz bidimensional en el eje coronoal (segundo eje) de la matriz tridimensional H.
  CORONAL_VIEW = H[:, j, :]
  # selecciona la k-ésima matriz bidimensional en el eje axial (tercer eje) de la matriz tridimensional H.
  SAGITTAL_VIEW = H[:, :, k]
  return AXIAL_VIEW, CORONAL_VIEW, SAGITTAL_VIEW

# %% [markdown]
# Ejecute esta celda para reconstruir el tensor $H$ con $k=200$ componentes principales:

# %%
# No modifique, solo ejecute
M = rebuild_M(Vh, Y, mu, k=200)
H = M_to_tensor(M)

# %% [markdown]
# Ejecute esta celda para comprobar su función `get_views`:

# %%
# No modifique, solo ejecute
AXIAL_VIEW, CORONAL_VIEW, SAGITTAL_VIEW = get_views(H, coor=(164, 240, 240))

fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(AXIAL_VIEW, cmap=plt.cm.gray)
axes[0].set_title("Axial view")

axes[1].imshow(CORONAL_VIEW, cmap=plt.cm.gray)
axes[1].set_title("Coronal view")

axes[2].imshow(SAGITTAL_VIEW, cmap=plt.cm.gray)
axes[2].set_title("Sagittal view")

for ax in axes:
  ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 2.3 **(5 puntos)** A continuación se muestran todos los ejes y sus imágenes correspondientes reconstruidas con $k=200$ componentes principales.

# %%
# No modifique, solo ejecute
viewer = SliceViewer3D(H, fun=get_views)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Pregunta 3
#
# Debido a una colisión con un asteroide, la nave de los extraterrestres tendrá que desechar al espacio algunas de las unidades de información en las que están guardadas los componentes de la matriz $Vh$ para eliminar la turbulencia. Para esto, saben que usted es experto en la compresión de imágenes y lo teletransportan a su nave en busca de su ayuda.

# %% [markdown]
# 3.1 **(10 puntos)** Exprese la función $f$ que describa el valor de la varianza preservada en términos de algunas de las variables entregadas, i.e. `(Vh, Y, S, mu)` y utilizando $k$ vectores singulares con $k=1,...,400$ de manera que pueda determinar cuantas unidades de información se deberán expulsar de la nave espacial.

# %% [markdown]
# **Respuesta:**
#
# ---
#
# *Reemplace este texto por su respuesta.*
#
# ---

# %% [markdown]
# 3.2 **(10 puntos)** Implemente la función $f$ utilizando la expresión anterior. Es tarea de usted determinar qué variables le serán de utilidad para el cálculo.

# %%
def f(Vh, Y, S, mu, k):
  """
  input:
  Vh  :(ndarray) array of the principal components.
  Y   :(ndarray) array of projected coefficients.
  S   :(ndarray) array of singular values.
  mu  :(ndarray) 1D array of averages per column of original data.
  k   :(int)     number of principal components to use.

  output:
  r   :(float)   total variance preserved using k components.
  """
  # acá va su código
  #--------------------------

  #--------------------------
  return r

# %%
# No modifique, solo ejecute

# Creación del dominio
dom = np.int16(np.linspace(1, 400, 400))

# Vectorización de la función
f_vec = np.vectorize(lambda k: f(Vh, Y, S, mu, k))

# %% [markdown]
# 3.3 **(15 puntos)** Ejecute la siguiente celda para graficar la función $f$ en todo el dominio y analice los resultados. ¿Qué información puede extraer del gráfico? Fundamente.

# %%
# No modifique, solo ejecute

# Gráfico de la función
plt.figure(figsize=(10, 6))

plt.plot(dom, f_vec(dom), label='Recorrido f(x)', marker='o', linestyle='-', markersize=3)
plt.ylabel('f(x)')
plt.xlabel('x')

plt.yticks(np.arange(0, 1.1, 0.05)) 
plt.ylim(0, 1) 
plt.grid(axis='both')

plt.legend(loc='best')
plt.title('Gráfico f(x)')
plt.show()

# %% [markdown]
# **Respuesta:**
#
# ---
#
# *Reemplace este texto por su respuesta.*
#
# ---

# %% [markdown]
# 3.4 **(10 puntos)** Implemente la función `find_k`, la cual a partir de una función $f$ y un porcentaje $delta \in [0,1]$ deseado de varianza a preservar, este calcule el valor $k$ de componentes necesarios.
# Finalmente, utilice esta función para darle una respuesta a los marcianos sobre cuántas unidades de información deben sacar de la nave, considerando que ellos necesitan preservar el $94.397316\%$ de la información de los datos.
#
# *Hint: consider using the previous function and avoid exhaustive search having in mind that there are better methods.*

# %%
def find_k(f, delta):
    """
    input:
    f       :(callable) vectorized function from 3.2.
    delta   :(float)    percentage of information to be preserved.
    
    output:
    k       :(int)      number of components to use to preserve delta of information.
    """
    # acá va su código
    #--------------------------

    #--------------------------
    return k

# %% [markdown]
# En la siguiente celda defina el valor de delta para luego evaluar la función anterior.

# %%
# Aquí definir el valor de delta. Solo cambie el 1 por el valor que usted está definiendo como delta.
delta = 1

# %%
# No modifique, solo ejecute
best_k = find_k(f_vec, delta)
best_k

# %% [markdown]
# **Respuesta:**
#
# ---
#
# *Reemplace este texto por su respuesta.*
#
# ---

# %% [markdown]
# 3.5 **(15 puntos)** ¡Excelente!, ahora proponga un $k$ ocupando el método del *Ojímetro* respecto al gráfico en 3.3, reconstruya las imágenes y compare el $k$ que usted como profesional recomienda y el que quieren ocupar los marcianos para estabilizar la nave.
#
# Describa las diferencias que puede percibir y cuál es la mejor función a utilizar. Fundamente su respuesta en base a los contenidos.
#
# **A considerar**: el valor de $k$ elegido **debe** ser distinto del obtenido en la pregunta anterior y mostrar diferencia, pues el puntaje obtenido en esta pregunta será asignado en función de la calidad de su respuesta.

# %% [markdown]
# **Respuesta:**
#
# ---
#
# *Reemplace este texto por su respuesta.*
#
# ---

# %%
# acá va su código
#--------------------------

#--------------------------

# %% [markdown]
# **¡Ya ha llegado al final de la tarea 2! Ahora debe enviarla antes de las 23:55 hrs. del viernes 4 de octubre!**
#
# **Solo debe entregar este notebook. Recuerde que el archivo de entrega debe seguir el siguiente formato: “apellido1_apellido2_tarea_numero.ipynb” en minúsculas, y no olvide revisar el reglamento de tareas.**

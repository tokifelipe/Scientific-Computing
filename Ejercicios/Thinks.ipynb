# %%
import numpy as np
import matplotlib.pyplot as plt

4
# Out:
# 4

# %% [markdown]
# Crear valores equiespaciados
#
# En este contexto crearé todos los valores que va a tomar theta

# %%
Theta = np.linspace(0, 4*np.pi, 200)

# %% [markdown]
# Ahora definiré mi Y segun algún theta

# %%
Y = 6*np.cos(.5*Theta)*np.sin(Theta)


fig, ax = plt.subplots()
ax.plot(X, Y)
plt.grid()
plt.show()
